# %%
import pandas as pd

# %%
df = pd.read_csv("/content/analysis_id (1)(in).csv")
df.head(2)
# Out:
#    Unnamed: 0            date_hour     client device_type        time_zone  \
# 0           0  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 1           1  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
#
#   os_name        browser_name                  ad_unit    size     bidder  \
# 0   Linux  Chrome-85.04183133  div-gpt-ad-BT-D-Footers  728x90  onemobile
# 1   Linux  Chrome-85.04183133  div-gpt-ad-BT-D-Footers  728x90  rhythmone
#
#    ... sum_time_to_respond median  min_bid  max_bid  avg_bid  \
# 0  ...              6614.0    NaN  0.58520  0.58520   0.5852
# 1  ...              5171.0    NaN  0.33945  0.34875   0.3441
#
#    sum_2nd_highest_bid  sum_prebid_winning_bid  sum_winning_bid  sum_nobid  \
# 0               0.5852                  0.5852              NaN        NaN
# 1                  NaN                     NaN              NaN        NaN
#
#    sum_timeout
# 0          NaN
# 1          NaN
#
# [2 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5000 non-null   int64
#  1   date_hour               5000 non-null   object
#  2   client                  5000 non-null   object
#  3   device_type             5000 non-null   object
#  4   time_zone               5000 non-null   object
#  5   os_name                 5000 non-null   object
#  6   browser_name            5000 non-null   object
#  7   ad_unit                 5000 non-null   object
#  8   size                    5000 non-null   object
#  9   bidder                  5000 non-null   object
#  10  bid_range               5000 non-null   object
#  11  media_type              5000 non-null   object
#  12  request_count           5000 non-null   int64
#  13  response_count          5000 non-null   int64
# ...

# %%
df["bidder"].unique()
# Out:
# array(['onemobile', 'rhythmone', 'undertone', ' ', 'pulsepoint',
#        'pubmatic', 'triplelift', 'sharethrough', 'ix', 'medianet',
#        'appnexus', '33across', 'openx', 'emx_digital', 'rubicon',
#        'criteo', 'sovrn', 'teads'], dtype=object)

# %%
bidder_info = df.groupby("bidder").agg( total_bids = ("bidder", "size"), wins = ("win_count","sum"))

bidder_info["win_rate"] = bidder_info["wins"]/bidder_info["total_bids"]

# %%
winner_bidder = bidder_info["win_rate"].idxmax()

# %%
print(winner_bidder)
print(bidder_info["win_rate"])
# Out:
# teads
# bidder
#                 0.000000
# 33across        0.079167
# appnexus        0.050761
# criteo          0.068627
# emx_digital     0.118343
# ix              0.028017
# medianet        0.052083
# onemobile       0.085995
# openx           0.035533
# pubmatic        0.191275
# pulsepoint      0.037313
# rhythmone       0.073171
# rubicon         0.000000
# sharethrough    0.071942
# sovrn           0.009804
# teads           0.333333
# triplelift      0.043103
# undertone       0.326531
# Name: win_rate, dtype: float64

# %% [markdown]
# Q1 : Describe how you would build a logistic regression model to predict the probability of a bid winning (win) based on the other columns.
# What features would you select and why? A1 : To build a logisctic regression model, there are certains steps that one must follow.
#
# -> Understanding the problem statemnt and the Data

# %%
Q1 : Describe how you would build a logistic regression model to predict the probability of a bid winning (win) based on the other columns.
What features would you select and why?

A1 : To build a logisctic regression model, there are certains steps that one must follow.

-> Understanding the problem statemnt and the Data
-> EDA (inlcudes Handling missing values and Outliers)
-> Feautre Selection - Feature selection is a crucial part and depends heavily on the avaibale data set. Domain knowledge is essential here. Sometimes avaliable feautres, individually on its own does amount to any output, but combining them can let us see a better picture. This is called feature engineering.
                        Apart from the SMEs, we also have feature selections techniques like RFE, Feautre Importnace from Tree Based Model, Z-Score, Etc which also helps in deciding which feautres can be useful in getting the desired prediction.
-> Handling categorical features
-> Splitting the target vairable and features
-> Train - Test split
-> Scaling the vairables/features
-> Model Training
-> Model Prediction and Evaluation

# %%
Q2 : Part 2: Based on the following results from a logistic regression model trained on the dataset, interpret the coefficients:
bid_amount: Coefficient = 0.8
time_to_bid: Coefficient = -0.4
ad_unit_A: Coefficient = 0.3

A2 :
-> bid_amount: For every unit increase in bid amount, the log-odds of winning increase by the coef of bid_amount. This basically suggests that higger bids are assosciated with a higher probability of winning.
-> time_to_bid: for every unit increase in time to bid, the log-odds of winning decrease by the coef of time_to_bid. This  suggests that bidding later is assosicated with a lower probab of winning
-> ad_uit_A: Now in comparison to ad_unit_B, ad_unit_A has a "0.3" higher log odds of winning. this suggests that ad_unit_A is more likely to result in a win than ad_unit_B
